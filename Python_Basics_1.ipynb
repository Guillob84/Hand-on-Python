# %% [markdown]
# <a href="https://colab.research.google.com/github/Guillob84/Hand-on-Python/blob/main/Python_Basics_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
